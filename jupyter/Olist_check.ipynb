# %%
import pandas as pd

# %%
df=pd.read_csv("../data/raw/customers_cap.csv")
df
# Out:
#                             customer_id          region       city    cap
# 0      4e7b3e00288586ebd08712fdd0374a03        Campania  Benevento  82100
# 1      4f2d8ab171c80ec8364f7c12e35b23ad  Emilia Romagna    Bologna  40121
# 2      fd826e7cf63160e536e0908c76c3f441        Campania    Salerno  84121
# 3      6f92779347724b67e44e3224f3b4cffd  Emilia Romagna     Modena  41121
# 4      261cb4f92498ca05d5bd1a327a261d9c  Emilia Romagna      Parma  43121
# ...                                 ...             ...        ...    ...
# 99436  721597f917f48a34ca1712b58166ddee       Lombardia     Varese  21100
# 99437  d8e3846d82e712608dfda713b5929998       Lombardia     Varese  21100
# 99438  573b52edbe089b1124b9ab66535e07d6       Lombardia     Varese  21100
# 99439  7fcd8494fc0c228c991aafe0770b08b4       Lombardia     Varese  21100
# 99440  d85919cb3c0529589c6fa617f5f43281       Lombardia     Varese  21100
#
# [99441 rows x 4 columns]

# %%
df=pd.read_csv("../data/raw/olistIT_categories.csv")
df
# Out:
#    product_category_name_english product_category_name_italian
# 0                  health_beauty               salute_bellezza
# 1          computers_accessories         informatica_accessori
# 2                           auto                          auto
# 3                 bed_bath_table            letto_bagno_tavola
# 4                furniture_decor            mobili_decorazione
# ..                           ...                           ...
# 66                       flowers                         fiori
# 67         arts_and_craftmanship            arti_e_artigianato
# 68           diapers_and_hygiene              pannolini_igiene
# 69     fashion_childrens_clothes    moda_abbigliamento_bambini
# 70         security_and_services           sicurezza_e_servizi
#
# [71 rows x 2 columns]

# %%
df=pd.read_csv("../data/raw/olistIT_products.csv")
df
# Out:
#                              product_id                   category  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        art
# 2      96bd76ec8810374ed1b65e291975717f             sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       baby
# 4      9dc1a7de274444849c219cff195d0b71                 housewares
# ...                                 ...                        ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor
# 32947  bf4538d88321d0fd4412a93c974510e6  construction_tools_lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table
# 32949  83808703fc0706a22e264b9d75f04a2e      computers_accessories
# 32950  106392145fca363410d287a815be6de4             bed_bath_table
#
#        product_name_lenght  product_description_lenght  product_photos_qty
# 0                     40.0                       287.0                 1.0
# ...

# %%
df=pd.read_csv("../data/raw/olistIT_orders.csv")
df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp order_delivered_customer_date  \
# ...

# %%
df=pd.read_csv("../data/raw/olistIT_sellers.csv")
df
# Out:
#                              seller_id    region
# 0     3442f8959a84dea7ee197c632cb2df15     Lazio
# 1     d1b65fc7debc3361ea86b5f14c68d2e2     Lazio
# 2     ce3ad9de960102d0677a81f5d0bb7b2d  Piemonte
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3     Lazio
# 4     51a04a8a6bdcb23deccc82b0b80742cf     Lazio
# ...                                ...       ...
# 3090  98dddbc4601dd4443ca174359b237166   Liguria
# 3091  f8201cab383e484733266d1906e2fdfa   Abruzzo
# 3092  74871d19219c7d518d0090283e03c137     Lazio
# 3093  e603cf3fec55f8697c9059638d6c8eb5  Sardegna
# 3094  9e25199f6ef7e7c347120ff175652c3b     Lazio
#
# [3095 rows x 2 columns]

# %%
df=pd.read_csv("../data/raw/olistIT_orders_products.csv")
df
# Out:
#                                 order_id  order_item  \
# 0       00010242fe8c5a6d1ba2dd792cb16214           1
# 1       00018f77f2f0320c557190d7a144bdd3           1
# 2       000229ec398224ef6ca0657da4fc703e           1
# 3       00024acbcdf0a6daa1e931b038114c75           1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9           1
# ...                                  ...         ...
# 112645  fffc94f6ce00a00581880bf54a75a037           1
# 112646  fffcd46ef2263f404302a634eb57f7eb           1
# 112647  fffce4705a9662cd70adb13d4a31832d           1
# 112648  fffe18544ffabc95dfada21779c9644f           1
# 112649  fffe41c64501cc87c801fd61db3f6244           1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# ...
